# %% [markdown]
# # Let's Start

# %% [markdown]
# # Introduction or Problem Statement Discussion

# %% [raw]
# A Chinese car company, Geely Auto, plans to enter the United States market by setting up a manufacturing unit and producing cars locally. Their goal is to compete with established American and European car manufacturers. To achieve this, they need to understand what factors influence car prices in the U.S., as these factors may be very different from those in the Chinese market. They are particularly interested in identifying which variables are important for predicting a car's price and how well these variables explain the pricing.
#
# To help with this, a consulting firm has gathered a large dataset containing information about various cars in the U.S. market. This data will be analyzed to uncover the key factors affecting car prices, enabling Geely Auto to price their cars competitively. The task is presented as an exciting and adventurous journey into the world of cars, where we will explore data, solve mysteries, and uncover insights! 🚗

# %% [markdown]
# # Dataset Columns Information

# %% [raw]
# 1. CarID: Identification Number for Each Car
# 2. SafetyRating: Car's Safety Rating
# 3. CarName: Name of the Car Model
# 4. FuelType: Type of Fuel Used (Gasoline, Diesel, Electric, etc.)
# 5. Aspiration: Type of Aspiration (Standard or Turbocharged)
# 6. NumDoors: Number of Doors on the Car
# 7. BodyStyle: Style of the Car's Body (Sedan, Coupe, SUV, etc.)
# 8. DriveWheelType: Type of Drive Wheels (Front, Rear, All)
# 9. EngineLocation: Location of the Car's Engine (Front or Rear)
# 10. Wheelbase: Length of the Car's Wheelbase
# 11. CarLength: Overall Length of the Car
# 12. CarWidth: Width of the Car
# 13. CarHeight: Height of the Car
# 14. CurbWeight: Weight of the Car without Passengers or Cargo
# 15. EngineType: Type of Engine (Gas, Diesel, Electric, etc.)
# 16. NumCylinders: Number of Cylinders in the Engine
# 17. EngineSize: Size of the Car's Engine
# 18. FuelSystem: Type of Fuel Delivery System
# 19. BoreRatio: Bore-to-Stroke Ratio of the Engine
# 20. Stroke: Stroke Length of the Engine
# 21. CompressionRatio: Compression Ratio of the Engine
# 22. Horsepower: Car's Engine Horsepower
# 23. PeakRPM: Engine's Peak RPM (Revolutions Per Minute)
# 24. CityMPG: Miles Per Gallon (MPG) in City Driving
# 25. HighwayMPG: MPG on the Highway
# 26. CarPrice: Price of the Car

# %% [markdown]
# # Cycle of the Project

# %% [raw]
# # Understanding the Problem Statement
# # Data Checks to Perform
# # Exploratory Data Analysis
# # Data Pre-Processing
# # Model Training
# # Choose Best Model

# %% [markdown]
# # 1.Problem Statement

# %% [raw]
# Predicting the price of cars based on a wide range of attributes and features. Using a dataset containing car details such as safety ratings, dimensions, engine specifications, and more, we aim to develop a machine learning model that accurately estimates the price of different car models.

# %% [markdown]
# # Import Modules

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("F:/AI Data and Projects/AI Projects/20.Old Cars Dataset/CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %% [markdown]
# # Data Checks to Perform

# %%
# Check Missing Values 
# Check Duplicates
# Check Data Type
# Check the number of unique values of each column
# Check statistics of the dataset 
# Check various categories present in the different categorical columns

# %%
# Check Missing Values
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# Check the Duplications
df.duplicated().sum()
# Out:
# 0

# %%
# NO Duplication

# %%
# Check the datatype
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
# Check the number of unique values of each column
df.nunique()
# Out:
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
# Check statistics of data set
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# # Insights from Statistics

# %%
# Car Variety:
    # > Dataset Covers 205 cars models
    # > Sizes, Weights , and engine capacity may vary 

# Price Range:
    # > Minimum prices: 5,118 dollars
    # > Maximum prices: 45,400 dollars
    # > Average prices: 13,276 dollars
# Engine Diversity:
    # > Engine differ in bore diameter and stroke lenght
    # > Risk ratings vary form -2 to 3

# %%
categorical_columns = ['fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation','enginetype',
    'cylindernumber',
    'fuelsystem'
]

for col in categorical_columns:
    
    print(f"Category in {col} is : {df[col].unique()}")
# Out:
# Category in fueltype is : ['gas' 'diesel']
# Category in aspiration is : ['std' 'turbo']
# Category in doornumber is : ['two' 'four']
# Category in carbody is : ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# Category in drivewheel is : ['rwd' 'fwd' '4wd']
# Category in enginelocation is : ['front' 'rear']
# Category in enginetype is : ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# Category in cylindernumber is : ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# Category in fuelsystem is : ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']

# %% [markdown]
# # 3.EDA

# %%
numerical_features = ['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
                      'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
                      'peakrpm', 'citympg', 'highwaympg', 'price']

plt.figure(figsize=(12, 8))
for feature in numerical_features:
    plt.subplot(3, 5, numerical_features.index(feature) + 1)
    sns.histplot(data=df[feature], bins=20, kde=True)
    plt.title(feature)
plt.tight_layout()
plt.show()

# %%
# Price Analysis
plt.figure(figsize=(8, 6))
sns.histplot(data=df['price'], bins=20, kde=True)
plt.title('Distribution of Price')
plt.show()

# %%
categorical_columns = ['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel',
                       'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']

# Create subplots
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(12, 9))
axes = axes.ravel()  # Flatten the 2D array of axes

# Loop through each categorical column
for i, column in enumerate(categorical_columns):
    sns.countplot(x=df[column], data=df, palette='bright', ax=axes[i], saturation=0.95)
    for container in axes[i].containers:
        axes[i].bar_label(container, color='black', size=10)
    axes[i].set_title(f'Count Plot of {column.capitalize()}')
    axes[i].set_xlabel(column.capitalize())
    axes[i].set_ylabel('Count')

# Adjust layout and show plots
plt.tight_layout()
plt.show()

# %%
n = 20  # Number of top car models to plot
top_car_models = df['CarName'].value_counts().head(n)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_car_models.values, y=top_car_models.index)
plt.title(f'Top {n} Car Models by Frequency')
plt.xlabel('Frequency')
plt.ylabel('Car Model')
plt.tight_layout()
plt.show()

# %%
# Calculate average price for each car model
avg_prices_by_car = df.groupby('CarName')['price'].mean().sort_values(ascending=False)

# Plot top N car models by average price
n = 20  # Number of top car models to plot
top_car_models = avg_prices_by_car.head(n)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_car_models.values, y=top_car_models.index)
plt.title(f'Top {n} Car Models by Average Price')
plt.xlabel('Average Price')
plt.ylabel('Car Model')
plt.tight_layout()
plt.show()

# %%
# Categorical Feature vs. Price
plt.figure(figsize=(12, 8))
for feature in categorical_columns:
    plt.subplot(3, 3, categorical_columns.index(feature) + 1)
    sns.boxplot(data=df, x=feature, y='price')
    plt.title(f'{feature} vs. Price')
plt.tight_layout()
plt.show()

# %%
# Correlation Analysis
correlation_matrix = df[numerical_features].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Analysis Results

# %%
# We have Dataset > Car Price
# The Shape DataSet=(Rows = 205, Columns=26)
# No Null Values
# No Duplicated Value
#.................#

# Some Analyst

# Price Cars:
    # Avg price = $13,276
    # Min Price = $5,118
    # Max Price = $45,400

# %% [markdown]
# # Final Outputs or Result

# %% [raw]
# Toyota stands out as the most popular car brand, with its models appearing frequently among users. Most cars run on gas, comprising about 90% of the total, and their average price is lower compared to cars that use diesel. While cars running on diesel make up around 10%, their average price tends to be higher than those powered by gas.
#
# Regarding turbocharged engines, approximately 82% of cars do not have a turbocharger, and their average price is lower. In contrast, turbocharged cars make up about 18% but come with a higher average price.
#
# When it comes to the number of doors, around 56% of users prefer cars with four doors, while 46% choose cars with two doors. Interestingly, sports cars with two doors maintain a similar average price to their four-door counterparts.
#
# In terms of car body type, sedans are the most popular choice among users, likely due to their practicality. However, higher-priced body types like convertibles and hardtops also enjoy some popularity.
#
# Front-wheel drive (FWD) is the most commonly used drivetrain, likely because of its affordability. Lastly, the "ohc" engine type is the most prevalent, and it is often associated with lower-priced cars.
